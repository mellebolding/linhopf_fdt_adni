# %%
import importlib
import numpy as np
import src.data_loaders.ADNI_A as ADNI_A
import src.data_processing.filterps as filterps
import src.data_processing.zfilterts as zfilterts
import LinHopfFit
from typing import Union
importlib.reload(LinHopfFit)
# Out:
# <module 'LinHopfFit' from '/Users/mellebolding/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py'>

# %%
NPARCELLS = 40 # max 379
a_param = -0.02
gconst = 1.0
avec = a_param * np.ones(NPARCELLS)
sigma_mean = 0.45
sigma_ini = sigma_mean * np.ones(NPARCELLS)

## hyperparams
hopfParamsAdam = {
'verbose': True,
'fit_sigma': True,
'fit_a': True,
'competitive_coupling': False,
'allow_negative': False,
'loss_weights': {'mse_fc': 0.25, 'mse_covtau': 0.25, 'corr_fc': 0.25, 'corr_covtau': 0.25},
'lr_Ceff': 1e-4,
'lr_sigma': 1e-4,
'lr_a': 5e-4,
'beta1': 0.9,
'beta2': 0.999,
'epsilon': 1e-8,
'max_iter': 10,
'iter_check': 50,
'patience': 5,
'maxC': 0.2,
'TR': 3,
'g': 1,
'tau': 1.0,
}

# %%
# Loading the timeseries data for all subjects and dividing them into groups

DL = ADNI_A.ADNI_A(normalizeBurden=False)
HC_IDs = DL.get_groupSubjects('HC')
HC_MRI = {}
HC_SC = {}
f_diff_HC = {}
for subject in HC_IDs:
    data = DL.get_subjectData(subject,printInfo=False)
    HC_MRI[subject] = data[subject]['timeseries'].T
    HC_SC[subject] = data[subject]['SC']
    f_diff_HC[subject] = filterps.calc_H_freq(HC_MRI[subject], 3000, filterps.FiltPowSpetraVersion.v2021)[0]
MCI_IDs = DL.get_groupSubjects('MCI')
MCI_MRI = {}
MCI_SC = {}
f_diff_MCI = {}
for subject in MCI_IDs:
    data = DL.get_subjectData(subject,printInfo=False)
    MCI_MRI[subject] = data[subject]['timeseries'].T
    MCI_SC[subject] = data[subject]['SC']
    f_diff_MCI[subject] = filterps.calc_H_freq(MCI_MRI[subject], 3000, filterps.FiltPowSpetraVersion.v2021)[0]
AD_IDs = DL.get_groupSubjects('AD')
AD_MRI = {}
AD_SC = {}
f_diff_AD = {}
for subject in AD_IDs:
    data = DL.get_subjectData(subject,printInfo=False)
    AD_MRI[subject] = data[subject]['timeseries'].T
    AD_SC[subject] = data[subject]['SC']
    f_diff_AD[subject] = filterps.calc_H_freq(AD_MRI[subject], 3000, filterps.FiltPowSpetraVersion.v2021)[0]

all_MRI = {**HC_MRI, **MCI_MRI, **AD_MRI}
all_SC = {**HC_SC, **MCI_SC, **AD_SC}
all_ID= [*HC_IDs, *MCI_IDs, *AD_IDs]
all_f_diff = {**f_diff_HC, **f_diff_MCI, **f_diff_AD}

# %%
min_ntimes = min(all_MRI[subj_id].shape[0] for subj_id in all_ID)
ts_gr_arr = np.zeros((len(all_ID), NPARCELLS, min_ntimes))

for sub in range(len(all_ID)):
    subj_id = all_ID[sub]
    ts_gr_arr[sub,:,:] = all_MRI[subj_id][:min_ntimes,:NPARCELLS].T.copy() 
TSemp_zsc = zfilterts.zscore_time_series(ts_gr_arr, mode='global', detrend=True)[:,:NPARCELLS,:].copy() #mode: parcel, global, none

# %%
param_grid = {
    'lr_Ceff': [1,1e-5, 5e-5, 1e-4, 5e-4],
    'lr_sigma': [1e-5, 5e-5, 1e-4, 5e-4],
    'lr_a': [1e-4, 5e-4, 1e-3, 5e-3],
    'beta1': [0.85, 0.9, 0.95],
    'beta2': [0.99, 0.999],
    'epsilon': [1e-9, 1e-8, 1e-7],
}

def sensitivity_analysis():
    """Test each parameter individually to see which matter most"""
    baseline = {
        'lr_Ceff': 1e-4,
        'lr_sigma': 1e-4,
        'lr_a': 5e-4,
        'beta1': 0.9,
        'beta2': 0.999,
        'epsilon': 1e-8,
        'max_iter': 1000,
        'iter_check': 50,
        'patience': 5,
        'maxC': 0.2,
        'TR': 3,
        'g': 1,
        'tau': 1.0,
        'verbose': False,
        'fit_sigma': True,
        'fit_a': True,
        'competitive_coupling': False,
        'allow_negative': False,
        'loss_weights': {'mse_fc': 0.25, 'mse_covtau': 0.25, 'corr_fc': 0.25, 'corr_covtau': 0.25},
    }
    
    sensitivity = {}
    
    for param_name, param_values in param_grid.items():
        param_results = []
        
        for val in param_values:
            params = baseline.copy()
            params[param_name] = val
            
            mse_list = []
            for sub in range(len(all_ID)):
                subj_id = all_ID[sub]
                SC = all_SC[subj_id][:NPARCELLS, :NPARCELLS]
                f_diff = all_f_diff[subj_id][:NPARCELLS]
                
                model = LinHopfFit.LinearHopfModel(C=SC, f_diff=f_diff, 
                                                   sigma=sigma_ini, a=avec, 
                                                   **params)
                model.setup_optimization(optimizer_method='adam', **params)
                Ceff_sub, sigma_sub, a_sub, err_mse= model.fit(TSemp_zsc[sub])
                mse_list.append(err_mse)
            
            avg_mse = np.mean(mse_list)
            param_results.append((val, avg_mse))
            print(f"{param_name} = {val}: MSE = {avg_mse:.6f}")
        
        sensitivity[param_name] = param_results
    
    return sensitivity

sensitivity = sensitivity_analysis()
# Out:
# lr_Ceff = 1: MSE = 0.124189
# lr_Ceff = 1e-05: MSE = 0.156948
# lr_Ceff = 5e-05: MSE = 0.137734
# lr_Ceff = 0.0001: MSE = 0.130431
# lr_Ceff = 0.0005: MSE = 0.119666
# lr_sigma = 1e-05: MSE = 0.128834
# lr_sigma = 5e-05: MSE = 0.129553
# lr_sigma = 0.0001: MSE = 0.130431
# lr_sigma = 0.0005: MSE = 0.140807
# lr_a = 0.0001: MSE = 0.124471
# lr_a = 0.0005: MSE = 0.130431
# lr_a = 0.001: MSE = 0.136566
# lr_a = 0.005: MSE = 0.146320
# beta1 = 0.85: MSE = 0.130554
# beta1 = 0.9: MSE = 0.130431
# beta1 = 0.95: MSE = 0.130006
# beta2 = 0.99: MSE = 0.132565
# beta2 = 0.999: MSE = 0.130431
# epsilon = 1e-09: MSE = 0.130431
# epsilon = 1e-08: MSE = 0.130431
# epsilon = 1e-07: MSE = 0.130431

# %%
def bayesian_optimization(n_trials=100):
    """Use Optuna for Bayesian optimization"""
    import optuna
    
    def objective(trial):
        params = {
            'lr_Ceff': trial.suggest_float('lr_Ceff', 1e-5, 1e-3, log=True),
            'lr_sigma': trial.suggest_float('lr_sigma', 1e-5, 1e-3, log=True),
            'lr_a': trial.suggest_float('lr_a', 1e-4, 5e-3, log=True),
            'beta1': trial.suggest_float('beta1', 0.85, 0.95),
            'beta2': trial.suggest_float('beta2', 0.99, 0.999),
            'epsilon': trial.suggest_float('epsilon', 1e-9, 1e-7, log=True),
            'max_iter': 10000,
            'iter_check': 50,
            'patience': 5,
            'maxC': 0.2,
            'TR': 3,
            'g': 1,
            'tau': 1.0,
            'verbose': False,
            'fit_sigma': True,
            'fit_a': True,
            'competitive_coupling': False,
            'allow_negative': False,
            'loss_weights': {'mse_fc': 0.25, 'mse_covtau': 0.25, 'corr_fc': 0.25, 'corr_covtau': 0.25},
        }
        
        mse_list = []
        for sub in range(len(all_ID)):
            subj_id = all_ID[sub]
            SC = all_SC[subj_id][:NPARCELLS, :NPARCELLS]
            f_diff = all_f_diff[subj_id][:NPARCELLS]
            
            model = LinHopfFit.LinearHopfModel(C=SC, f_diff=f_diff, 
                                               sigma=sigma_ini, a=avec, 
                                               **params)
            model.setup_optimization(optimizer_method='adam',**params)
            Ceff_sub, sigma_sub, a_sub, err_mse = model.fit(TSemp_zsc[sub])
            mse_list.append(err_mse)
        
        return np.mean(mse_list)
    
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
    
    print(f"\nBest MSE: {study.best_value:.6f}")
    print("Best parameters:")
    for key, value in study.best_params.items():
        print(f"  {key}: {value}")
    
    return study.best_params, study

bayesian_optimization(n_trials=5)
# Out:
# [I 2025-10-02 15:31:36,004] A new study created in memory with name: no-name-8ff26822-1538-4fda-969e-ad98d2e64265
#   0%|          | 0/50 [00:00<?, ?it/s]
# Early stopping: no improvement for 5 checks
# Error=0.026830, CorrFC=0.819, CorrCOV=0.738
# Early stopping: no improvement for 5 checks
# Error=0.023512, CorrFC=0.844, CorrCOV=0.675
# Early stopping: no improvement for 5 checks
# Error=0.030786, CorrFC=0.849, CorrCOV=0.741
# Early stopping: no improvement for 5 checks
# Error=0.030319, CorrFC=0.810, CorrCOV=0.734
# Early stopping: no improvement for 5 checks
# Error=0.032354, CorrFC=0.876, CorrCOV=0.757
# Early stopping: no improvement for 5 checks
# Error=0.034551, CorrFC=0.877, CorrCOV=0.542
# Early stopping: no improvement for 5 checks
# Error=0.032048, CorrFC=0.870, CorrCOV=0.849
# Early stopping: no improvement for 5 checks
# Error=0.053938, CorrFC=0.888, CorrCOV=0.764
# Early stopping: no improvement for 5 checks
# Error=0.038747, CorrFC=0.839, CorrCOV=0.708
# Early stopping: no improvement for 5 checks
# Error=0.025564, CorrFC=0.866, CorrCOV=0.630
# Early stopping: no improvement for 5 checks
# Error=0.024870, CorrFC=0.867, CorrCOV=0.639
# Early stopping: no improvement for 5 checks
# Error=0.022493, CorrFC=0.845, CorrCOV=0.830
# Early stopping: no improvement for 5 checks
# Error=0.022241, CorrFC=0.918, CorrCOV=0.887
# Early stopping: no improvement for 5 checks
# Error=0.013369, CorrFC=0.871, CorrCOV=0.866
# Early stopping: no improvement for 5 checks
# Error=0.027261, CorrFC=0.836, CorrCOV=0.821
# Early stopping: no improvement for 5 checks
# Error=0.028512, CorrFC=0.893, CorrCOV=0.839
# Early stopping: no improvement for 5 checks
# Error=0.037488, CorrFC=0.819, CorrCOV=0.642
# Early stopping: no improvement for 5 checks
# Error=0.036053, CorrFC=0.850, CorrCOV=0.737
# Early stopping: no improvement for 5 checks
# Error=0.035318, CorrFC=0.874, CorrCOV=0.804
# Early stopping: no improvement for 5 checks
# Error=0.020603, CorrFC=0.806, CorrCOV=0.576
# Early stopping: no improvement for 5 checks
# Error=0.032841, CorrFC=0.854, CorrCOV=0.602
# Early stopping: no improvement for 5 checks
# Error=0.038411, CorrFC=0.830, CorrCOV=0.790
# Early stopping: no improvement for 5 checks
# Error=0.013785, CorrFC=0.899, CorrCOV=0.864
# Early stopping: no improvement for 5 checks
# Error=0.026806, CorrFC=0.862, CorrCOV=0.692
# Early stopping: no improvement for 5 checks
# Error=0.021810, CorrFC=0.866, CorrCOV=0.765
# Early stopping: no improvement for 5 checks
# Error=0.014020, CorrFC=0.881, CorrCOV=0.824
# Early stopping: no improvement for 5 checks
# Error=0.017909, CorrFC=0.859, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.039525, CorrFC=0.844, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.024337, CorrFC=0.835, CorrCOV=0.519
# Early stopping: no improvement for 5 checks
# Error=0.048456, CorrFC=0.878, CorrCOV=-0.336
# Early stopping: no improvement for 5 checks
# Error=0.012881, CorrFC=0.735, CorrCOV=-0.071
# Early stopping: no improvement for 5 checks
# Error=0.034944, CorrFC=0.875, CorrCOV=0.709
# Early stopping: no improvement for 5 checks
# Error=0.024883, CorrFC=0.857, CorrCOV=0.811
# Early stopping: no improvement for 5 checks
# Error=0.021162, CorrFC=0.886, CorrCOV=0.605
# Early stopping: no improvement for 5 checks
# Error=0.020270, CorrFC=0.870, CorrCOV=0.837
# Early stopping: no improvement for 5 checks
# Error=0.012227, CorrFC=0.776, CorrCOV=0.049
# [I 2025-10-02 15:34:24,257] Trial 0 finished with value: 0.02780902102442833 and parameters: {'lr_Ceff': 8.73045832560552e-05, 'lr_sigma': 0.0001750564817339037, 'lr_a': 0.0004658478569180183, 'beta1': 0.8880872502461713, 'beta2': 0.9908563048444081, 'epsilon': 6.187194867974284e-08}. Best is trial 0 with value: 0.02780902102442833.
# Early stopping: no improvement for 5 checks
# Error=0.026830, CorrFC=0.819, CorrCOV=0.738
# Early stopping: no improvement for 5 checks
# Error=0.023512, CorrFC=0.844, CorrCOV=0.675
# Early stopping: no improvement for 5 checks
# Error=0.030786, CorrFC=0.849, CorrCOV=0.741
# Early stopping: no improvement for 5 checks
# Error=0.030319, CorrFC=0.810, CorrCOV=0.734
# Early stopping: no improvement for 5 checks
# Error=0.032354, CorrFC=0.876, CorrCOV=0.757
# Early stopping: no improvement for 5 checks
# Error=0.034551, CorrFC=0.877, CorrCOV=0.542
# Early stopping: no improvement for 5 checks
# Error=0.032048, CorrFC=0.870, CorrCOV=0.849
# Early stopping: no improvement for 5 checks
# Error=0.053938, CorrFC=0.888, CorrCOV=0.764
# Early stopping: no improvement for 5 checks
# Error=0.038747, CorrFC=0.839, CorrCOV=0.708
# Early stopping: no improvement for 5 checks
# Error=0.025564, CorrFC=0.866, CorrCOV=0.630
# Early stopping: no improvement for 5 checks
# Error=0.024870, CorrFC=0.867, CorrCOV=0.639
# Early stopping: no improvement for 5 checks
# Error=0.022493, CorrFC=0.845, CorrCOV=0.830
# Early stopping: no improvement for 5 checks
# Error=0.022241, CorrFC=0.918, CorrCOV=0.887
# Early stopping: no improvement for 5 checks
# Error=0.013369, CorrFC=0.871, CorrCOV=0.866
# Early stopping: no improvement for 5 checks
# Error=0.027261, CorrFC=0.836, CorrCOV=0.821
# Early stopping: no improvement for 5 checks
# Error=0.028512, CorrFC=0.893, CorrCOV=0.839
# Early stopping: no improvement for 5 checks
# Error=0.037488, CorrFC=0.819, CorrCOV=0.642
# Early stopping: no improvement for 5 checks
# Error=0.036053, CorrFC=0.850, CorrCOV=0.737
# Early stopping: no improvement for 5 checks
# Error=0.035318, CorrFC=0.874, CorrCOV=0.804
# Early stopping: no improvement for 5 checks
# Error=0.020603, CorrFC=0.806, CorrCOV=0.576
# Early stopping: no improvement for 5 checks
# Error=0.032841, CorrFC=0.854, CorrCOV=0.602
# Early stopping: no improvement for 5 checks
# Error=0.038411, CorrFC=0.830, CorrCOV=0.790
# Early stopping: no improvement for 5 checks
# Error=0.013785, CorrFC=0.899, CorrCOV=0.864
# Early stopping: no improvement for 5 checks
# Error=0.026806, CorrFC=0.862, CorrCOV=0.692
# Early stopping: no improvement for 5 checks
# Error=0.021810, CorrFC=0.866, CorrCOV=0.765
# Early stopping: no improvement for 5 checks
# Error=0.014020, CorrFC=0.881, CorrCOV=0.824
# Early stopping: no improvement for 5 checks
# Error=0.017909, CorrFC=0.859, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.039525, CorrFC=0.844, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.024337, CorrFC=0.835, CorrCOV=0.519
# Early stopping: no improvement for 5 checks
# Error=0.048456, CorrFC=0.878, CorrCOV=-0.336
# Early stopping: no improvement for 5 checks
# Error=0.012881, CorrFC=0.735, CorrCOV=-0.071
# Early stopping: no improvement for 5 checks
# Error=0.034944, CorrFC=0.875, CorrCOV=0.709
# Early stopping: no improvement for 5 checks
# Error=0.024883, CorrFC=0.857, CorrCOV=0.811
# Early stopping: no improvement for 5 checks
# Error=0.021162, CorrFC=0.886, CorrCOV=0.605
# Early stopping: no improvement for 5 checks
# Error=0.020270, CorrFC=0.870, CorrCOV=0.837
# Early stopping: no improvement for 5 checks
# Error=0.012227, CorrFC=0.776, CorrCOV=0.049
# [I 2025-10-02 15:37:12,357] Trial 1 finished with value: 0.02780902102442833 and parameters: {'lr_Ceff': 0.0008945394381169383, 'lr_sigma': 0.00010742930929949559, 'lr_a': 0.003582764494191732, 'beta1': 0.896500612298094, 'beta2': 0.9902434308535363, 'epsilon': 5.283773760752445e-08}. Best is trial 0 with value: 0.02780902102442833.
# Early stopping: no improvement for 5 checks
# Error=0.026830, CorrFC=0.819, CorrCOV=0.738
# Early stopping: no improvement for 5 checks
# Error=0.023512, CorrFC=0.844, CorrCOV=0.675
# Early stopping: no improvement for 5 checks
# Error=0.030786, CorrFC=0.849, CorrCOV=0.741
# Early stopping: no improvement for 5 checks
# Error=0.030319, CorrFC=0.810, CorrCOV=0.734
# Early stopping: no improvement for 5 checks
# Error=0.032354, CorrFC=0.876, CorrCOV=0.757
# Early stopping: no improvement for 5 checks
# Error=0.034551, CorrFC=0.877, CorrCOV=0.542
# Early stopping: no improvement for 5 checks
# Error=0.032048, CorrFC=0.870, CorrCOV=0.849
# Early stopping: no improvement for 5 checks
# Error=0.053938, CorrFC=0.888, CorrCOV=0.764
# Early stopping: no improvement for 5 checks
# Error=0.038747, CorrFC=0.839, CorrCOV=0.708
# Early stopping: no improvement for 5 checks
# Error=0.025564, CorrFC=0.866, CorrCOV=0.630
# Early stopping: no improvement for 5 checks
# Error=0.024870, CorrFC=0.867, CorrCOV=0.639
# Early stopping: no improvement for 5 checks
# Error=0.022493, CorrFC=0.845, CorrCOV=0.830
# Early stopping: no improvement for 5 checks
# Error=0.022241, CorrFC=0.918, CorrCOV=0.887
# Early stopping: no improvement for 5 checks
# Error=0.013369, CorrFC=0.871, CorrCOV=0.866
# Early stopping: no improvement for 5 checks
# Error=0.027261, CorrFC=0.836, CorrCOV=0.821
# Early stopping: no improvement for 5 checks
# Error=0.028512, CorrFC=0.893, CorrCOV=0.839
# Early stopping: no improvement for 5 checks
# Error=0.037488, CorrFC=0.819, CorrCOV=0.642
# Early stopping: no improvement for 5 checks
# Error=0.036053, CorrFC=0.850, CorrCOV=0.737
# Early stopping: no improvement for 5 checks
# Error=0.035318, CorrFC=0.874, CorrCOV=0.804
# Early stopping: no improvement for 5 checks
# Error=0.020603, CorrFC=0.806, CorrCOV=0.576
# Early stopping: no improvement for 5 checks
# Error=0.032841, CorrFC=0.854, CorrCOV=0.602
# Early stopping: no improvement for 5 checks
# Error=0.038411, CorrFC=0.830, CorrCOV=0.790
# Early stopping: no improvement for 5 checks
# Error=0.013785, CorrFC=0.899, CorrCOV=0.864
# Early stopping: no improvement for 5 checks
# Error=0.026806, CorrFC=0.862, CorrCOV=0.692
# Early stopping: no improvement for 5 checks
# Error=0.021810, CorrFC=0.866, CorrCOV=0.765
# Early stopping: no improvement for 5 checks
# Error=0.014020, CorrFC=0.881, CorrCOV=0.824
# Early stopping: no improvement for 5 checks
# Error=0.017909, CorrFC=0.859, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.039525, CorrFC=0.844, CorrCOV=0.792
# Early stopping: no improvement for 5 checks
# Error=0.024337, CorrFC=0.835, CorrCOV=0.519
# Early stopping: no improvement for 5 checks
# Error=0.048456, CorrFC=0.878, CorrCOV=-0.336
# Early stopping: no improvement for 5 checks
# Error=0.012881, CorrFC=0.735, CorrCOV=-0.071
# Early stopping: no improvement for 5 checks
# Error=0.034944, CorrFC=0.875, CorrCOV=0.709
# Early stopping: no improvement for 5 checks
# Error=0.024883, CorrFC=0.857, CorrCOV=0.811
# Early stopping: no improvement for 5 checks
# Error=0.021162, CorrFC=0.886, CorrCOV=0.605
# [W 2025-10-02 15:39:50,234] Trial 2 failed with parameters: {'lr_Ceff': 1.5534304204013356e-05, 'lr_sigma': 0.00015564067194783325, 'lr_a': 0.0003634444595296454, 'beta1': 0.9042339786126168, 'beta2': 0.9902905280222907, 'epsilon': 1.228782961523636e-08} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/36/v4_01lx92x3fjcp3w3df6mph0000gn/T/ipykernel_47144/2428796101.py", line 38, in objective
#     Ceff_sub, sigma_sub, a_sub, err_mse, corr_fc, corr_cov = model.fit(TSemp_zsc[sub])
#                                                              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mellebolding/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py", line 500, in fit
#     FCsim, COVsim, COVsimtotal, A = self._hopf_int(Ceff_current, sigma_current, a_current)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mellebolding/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py", line 634, in _hopf_int
#     Cvth = solve_sylvester(A, A.T, -Qn)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/linalg/_solvers.py", line 104, in solve_sylvester
#     y, scale, info = trsyl(r, s, f, tranb='C')
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-10-02 15:39:50,236] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 53
#      49         print(f"  {key}: {value}")
#      51     return study.best_params, study
# ---> 53 bayesian_optimization(n_trials=50)
#
# Cell In[15], line 44, in bayesian_optimization(n_trials)
#      41     return np.mean(mse_list)
#      43 study = optuna.create_study(direction='minimize')
# ---> 44 study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
#      46 print(f"\nBest MSE: {study.best_value:.6f}")
#      47 print("Best parameters:")
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[15], line 38, in bayesian_optimization.<locals>.objective(trial)
#      34     model = LinHopfFit.LinearHopfModel(C=SC, f_diff=f_diff,
#      35                                        sigma=sigma_ini, a=avec,
#      36                                        **params)
#      37     model.setup_optimization(optimizer_method='adam')
# ---> 38     Ceff_sub, sigma_sub, a_sub, err_mse, corr_fc, corr_cov = model.fit(TSemp_zsc[sub])
#      39     mse_list.append(err_mse)
#      41 return np.mean(mse_list)
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:500, in LinearHopfModel.fit(self, tsdata)
#     497 # Main optimization loop
#     498 for iteration in range(1, self.params['max_iter'] + 1):
#     499     # Forward pass
# --> 500     FCsim, COVsim, COVsimtotal, A = self._hopf_int(Ceff_current, sigma_current, a_current)
#     501     COVtausim = self._compute_covtau(COVsimtotal, A, COVsim)
#     503     # Compute loss and gradients
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:634, in LinearHopfModel._hopf_int(self, Ceff, sigma, a)
#     631 Qn = np.diag(np.concatenate([sigma**2, sigma**2]))
#     633 # Solve Sylvester equation
# --> 634 Cvth = solve_sylvester(A, A.T, -Qn)
#     636 # Extract FC and COV
#     637 FCth = corrcov_py_numba(Cvth)
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/linalg/_solvers.py:104, in solve_sylvester(a, b, q)
#     101 if trsyl is None:
#     102     raise RuntimeError('LAPACK implementation does not contain a proper '
#     103                        'Sylvester equation solver (TRSYL)')
# --> 104 y, scale, info = trsyl(r, s, f, tranb='C')
#     106 y = scale*y
#     108 if info < 0:
#
# KeyboardInterrupt:

# %%
# here we only run the subjects, group would take average SC and the group-specific TSemp_zscs (model.fit can take multiple timeseries at once)


for sub in range(len(all_ID)):
    subj_id = all_ID[sub]
    SC = all_SC[subj_id][:NPARCELLS, :NPARCELLS]
    f_diff = all_f_diff[subj_id][:NPARCELLS]
    #SC_N = (SC / np.max(SC)) * 0.2
    model = LinHopfFit.LinearHopfModel(C=SC, f_diff=f_diff, sigma=sigma_ini, a=avec, **hopfParamsAdam)
    model.setup_optimization(optimizer_method='lbfgs',**hopfParamsAdam)
    Ceff_sub, sigma_sub, a_sub, err_mse, corr_fc, corr_cov = model.fit(TSemp_zsc[sub])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 11
#       9 model = LinHopfFit.LinearHopfModel(C=SC, f_diff=f_diff, sigma=sigma_ini, a=avec, **hopfParamsAdam)
#      10 model.setup_optimization(optimizer_method='lbfgs',**hopfParamsAdam)
# ---> 11 Ceff_sub, sigma_sub, a_sub, err_mse, corr_fc, corr_cov = model.fit(TSemp_zsc[sub])
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:543, in LinearHopfModel.fit(self, tsdata)
#     540 grad_a = grads[4] + grads[5] if self.fit_a else np.zeros_like(a_current)
#     542 # Optimization step
# --> 543 Ceff_new, sigma_new, a_new = self.optimizer.step(
#     544     (Ceff_current, sigma_current, a_current),
#     545     (grad_Ceff, grad_sigma, grad_a),
#     546     self
#     547 )
#     549 # Apply constraints
#     550 Ceff_new = self._apply_Ceff_constraints(Ceff_new)
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:190, in Optimizer.step(self, params, grads, model)
#     188     return self._gd_step(params, grads)
#     189 elif self.method == 'lbfgs':
# --> 190     return self._lbfgs_step(params, grads, model)
#     191 elif self.method == 'particle_swarm':
#     192     return self._pso_step(params, model)
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:281, in Optimizer._lbfgs_step(self, params, grads, model)
#     278 x0 = np.concatenate([Ceff.flatten(), sigma, a])
#     280 # Run L-BFGS
# --> 281 result = minimize(objective, x0, method='L-BFGS-B', options={'maxiter': 10})
#     283 # Unpack results
#     284 n = model.n_parcels
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:345, in ScalarFunction.fun_and_grad(self, x)
#     343     self._update_x(x)
#     344 self._update_fun()
# --> 345 self._update_grad()
#     346 return self.f, self.g
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:48, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      46 def wrapped1(x, f0=None):
#      47     ncalls[0] += 1
# ---> 48     return approx_derivative(
#      49         fun, x, f0=f0, **finite_diff_options
#      50     )
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:523, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     520     use_one_sided = False
#     522 if sparsity is None:
# --> 523     return _dense_difference(fun_wrapped, x0, f0, h,
#     524                              use_one_sided, method)
#     525 else:
#     526     if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     594     x1[i] += h[i]
#     595     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 596     df = fun(x1) - f0
#     597 elif method == '3-point' and use_one_sided[i]:
#     598     x1[i] += h[i]
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:474, in approx_derivative.<locals>.fun_wrapped(x)
#     471 if xp.isdtype(x.dtype, "real floating"):
#     472     x = xp.astype(x, x0.dtype)
# --> 474 f = np.atleast_1d(fun(x, *args, **kwargs))
#     475 if f.ndim > 1:
#     476     raise RuntimeError("`fun` return value has "
#     477                        "more than 1 dimension.")
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:269, in Optimizer._lbfgs_step.<locals>.objective(x)
#     266 Ceff_test = model._apply_Ceff_constraints(Ceff_test)
#     268 # Compute loss
# --> 269 FCsim, COVsim, COVsimtotal, A = model._hopf_int(Ceff_test, sigma_vals, a_vals)
#     270 COVtausim = model._compute_covtau(COVsimtotal, A, COVsim)
#     272 loss, _ = model.loss_manager.compute_loss(
#     273     model.FCemp, FCsim, model.COVtauemp, COVtausim
#     274 )
#
# File ~/MSc/Thesis/linhopf_fdt_adni/LinHopfFit.py:636, in LinearHopfModel._hopf_int(self, Ceff, sigma, a)
#     633 Qn = np.diag(np.concatenate([sigma**2, sigma**2]))
#     635 # Solve Sylvester equation
# --> 636 Cvth = solve_sylvester(A, A.T, -Qn)
#     638 # Extract FC and COV
#     639 FCth = corrcov_py_numba(Cvth)
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/linalg/_solvers.py:94, in solve_sylvester(a, b, q)
#      91 r, u = schur(a, output='real')
#      93 # Compute the Schur decomposition of b
# ---> 94 s, v = schur(b.conj().transpose(), output='real')
#      96 # Construct f = u'*q*v
#      97 f = np.dot(np.dot(u.conj().transpose(), q), v)
#
# File /opt/homebrew/anaconda3/envs/fdt-env/lib/python3.12/site-packages/scipy/linalg/_decomp_schur.py:200, in schur(a, output, lwork, overwrite_a, sort, check_finite)
#     196     else:
#     197         raise ValueError("'sort' parameter must either be 'None', or a "
#     198                          "callable, or one of ('lhp','rhp','iuc','ouc')")
# --> 200 result = gees(sfunction, a1, lwork=lwork, overwrite_a=overwrite_a,
#     201               sort_t=sort_t)
#     203 info = result[-1]
#     204 if info < 0:
#
# KeyboardInterrupt:
